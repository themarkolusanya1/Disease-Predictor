# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
# 1. Load the dataset
file_path = "symptoms_Africa20.csv"

# %%
# 2. Read the CSV file
df = pd.read_csv(file_path)

# %%
print("Dataset shape:", df.shape)
# Out:
# Dataset shape: (20, 2)

# %%
# 3. Print dataset initialization details
print("=" * 65)
print("1. DATASET INITIALIZATION")
print("=" * 65)
print(f"Dataset Loaded Successfully: {file_path}")
print(f"Total Rows: {df.shape[0]} | Total Columns: {df.shape[1]}")
print(f"\nDetected Columns:\n{list(df.columns)}")
print("\nFirst 3 Rows of Raw Data:")
print(df.head(3))
# Out:
# =================================================================
# 1. DATASET INITIALIZATION
# =================================================================
# Dataset Loaded Successfully: symptoms_Africa20.csv
# Total Rows: 20 | Total Columns: 2
#
# Detected Columns:
# ['Disease', 'Description']
#
# First 3 Rows of Raw Data:
#          Disease                                        Description
# 0  Drug Reaction  An adverse drug reaction (ADR) is an injury ca...
# 1        Malaria  An infectious disease caused by protozoan para...
# 2        Allergy  An allergy is an immune system response to a f...

# %%
# 4. Separate Features (symptoms) and Target (disease)
X = df.drop(columns=["Disease"])
y = df["Disease"]

# %%
# 5. Encode Categorical Symptom Features into Numeric (0/1)
X_encoded = pd.get_dummies(X, drop_first=True).astype(int)

# %%
# 6. Encode Target Labels (Disease Names -> Numeric IDs)
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
# 7. Check total duplicate rows across the entire dataset
duplicate_count = df.duplicated().sum()

print(f"Total Exact Duplicate Rows Found: {duplicate_count}")
# Out:
# Total Exact Duplicate Rows Found: 0

# %%
# 8. Train / Test Split using shuffle=True (Preserves 100% of data & rare classes)
X_train, X_test, y_train, y_test = train_test_split(
    X_encoded, 
    y_encoded, 
    test_size=0.20, 
    random_state=42, 
    shuffle=True
)

# %%
# 9. Verify Results
print("=" * 65)
print("CLEANING & PREPROCESSING COMPLETE!")
print("=" * 65)
print(f"Cleaned Rows Retained: {len(X_encoded)} / {len(df)}")
print(f"X_train Shape        : {X_train.shape}")
print(f"X_test Shape         : {X_test.shape}")
print(f"y_train Shape        : {y_train.shape}")
print(f"y_test Shape         : {y_test.shape}")
print("=" * 65)
# Out:
# =================================================================
# CLEANING & PREPROCESSING COMPLETE!
# =================================================================
# Cleaned Rows Retained: 20 / 20
# X_train Shape        : (16, 19)
# X_test Shape         : (4, 19)
# y_train Shape        : (16,)
# y_test Shape         : (4,)
# =================================================================

# %%
# 2. Separate Features (X) and Target (y)
# Assuming 'Disease' is the target column
y_raw = df['Disease']
X_raw = df.drop(columns=['Disease'])

# %%
#3. Convert text into numbers
X = pd.get_dummies(X_raw).astype(int)

# %%
#4. Clean column headers (removes accidental leading/trailing spaces)
df.columns = df.columns.str.strip()

print("=" * 65)
print("1. DATASET INITIALIZATION")
print("=" * 65)
print(f"Dataset Loaded Successfully: {file_path}")
print(f"Total Rows: {df.shape[0]} | Total Columns: {df.shape[1]}")
print(f"\nDetected Columns:\n{list(df.columns)}")
print("\nFirst 3 Rows of Raw Data:")
print(df.head(3))
# Out:
# =================================================================
# 1. DATASET INITIALIZATION
# =================================================================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 7
#       3
#       4 print("=" * 65)
#       5 print("1. DATASET INITIALIZATION")
#       6 print("=" * 65)
# ----> 7 print(f"Dataset Loaded Successfully: {file_path}")
#       8 print(f"Total Rows: {df.shape[0]} | Total Columns: {df.shape[1]}")
#       9 print(f"\nDetected Columns:\n{list(df.columns)}")
#      10 print("\nFirst 3 Rows of Raw Data:")
#
# NameError: name 'file_path' is not defined
