# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
# 1. Load the dataset
file_path = "data/processed/dataset_Africa20.csv"

# %%
# 2. Read the CSV file
df = pd.read_csv(file_path)

# %%
# 3. Print dataset initialization details
print(f"Dataset Loaded Successfully: {file_path}")
print(f"Total Rows: {df.shape[0]} | Total Columns: {df.shape[1]}")
print(f"\nDetected Columns:\n{list(df.columns)}")
print("\nFirst 3 Rows of Raw Data:")
print(df.head(3))
# Out:
# Dataset Loaded Successfully: data/processed/dataset_Africa20.csv
# Total Rows: 146 | Total Columns: 18
#
# Detected Columns:
# ['Disease', 'Symptom_1', 'Symptom_2', 'Symptom_3', 'Symptom_4', 'Symptom_5', 'Symptom_6', 'Symptom_7', 'Symptom_8', 'Symptom_9', 'Symptom_10', 'Symptom_11', 'Symptom_12', 'Symptom_13', 'Symptom_14', 'Symptom_15', 'Symptom_16', 'Symptom_17']
#
# First 3 Rows of Raw Data:
#    Disease            Symptom_1  Symptom_2           Symptom_3  \
# 0  Allergy  continuous_sneezing  shivering              chills
# 1  Allergy            shivering     chills  watering_from_eyes
# 2  Allergy  continuous_sneezing     chills  watering_from_eyes
#
#             Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8 Symptom_9  \
# 0  watering_from_eyes       NaN       NaN       NaN       NaN       NaN
# 1                 NaN       NaN       NaN       NaN       NaN       NaN
# 2                 NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
# 4. Separate Features (symptoms) and Target (disease)
X = df.drop(columns=["Disease"])
y = df["Disease"]

# %%
# 5. Encode Categorical Symptom Features into Numeric (0/1)
X_encoded = pd.get_dummies(
    X,
    columns=X.columns,
    dummy_na=False
).astype(int)

# %%
# 6. Encode Target Labels (Disease Names -> Numeric IDs)
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
# 7. Check total duplicate rows across the entire dataset
duplicate_count = df.duplicated().sum()
print(f"Total Exact Duplicate Rows Found: {duplicate_count}")
# Out:
# Total Exact Duplicate Rows Found: 0

# %%
# 8. Train / Test Split using shuffle=True (Preserves 100% of data & rare classes)
X_train, X_test, y_train, y_test = train_test_split(
    X_encoded,
    y_encoded,
    test_size=0.20,
    random_state=42,
    stratify=y_encoded
)

# %%
# 9. Verify Results
print(f"Cleaned Rows Retained: {len(X_encoded)} / {len(df)}")
print(f"X_train Shape        : {X_train.shape}")
print(f"X_test Shape         : {X_test.shape}")
print(f"y_train Shape        : {y_train.shape}")
print(f"y_test Shape         : {y_test.shape}")
# Out:
# Cleaned Rows Retained: 146 / 146
# X_train Shape        : (116, 217)
# X_test Shape         : (30, 217)
# y_train Shape        : (116,)
# y_test Shape         : (30,)

# %%
# 10. Final Dataset Validation

# Verify there are no missing values
print("=" * 60)
print("MISSING VALUE CHECK")
print("=" * 60)
print(f"X_train Missing Values : {X_train.isnull().sum().sum()}")
print(f"X_test Missing Values  : {X_test.isnull().sum().sum()}")

# Verify class distribution
print("\n" + "=" * 60)
print("TRAINING CLASS DISTRIBUTION")
print("=" * 60)
print(pd.Series(y_train).value_counts().sort_index())

print("\n" + "=" * 60)
print("TESTING CLASS DISTRIBUTION")
print("=" * 60)
print(pd.Series(y_test).value_counts().sort_index())

# Verify feature data types
print("\n" + "=" * 60)
print("FEATURE DATA TYPES")
print("=" * 60)
print(X_train.dtypes.unique())
# Out:
# ...
# MISSING VALUE CHECK
# ...
# X_train Missing Values : 0
# X_test Missing Values  : 0
#
# ...
# TRAINING CLASS DISTRIBUTION
# ...
# 0     4
# 1     4
# 2     5
# 3     6
# 4     8
# 5     7
# 6     7
# 7     5
# 8     4
# 9     4
# 10    5
# 11    7
# 12    7
# 13    6
# 14    8
# 15    4
# 16    7
# 17    7
# 18    7
# 19    4
# Name: count, dtype: int64
#
# ...
# TESTING CLASS DISTRIBUTION
# ...
# 0     1
# 1     1
# 2     1
# 3     1
# 4     2
# 5     2
# 6     2
# 7     1
# 8     1
# 9     1
# 10    1
# 11    2
# 12    2
# 13    2
# 14    2
# 15    1
# 16    2
# 17    2
# 18    2
# 19    1
# Name: count, dtype: int64
#
# ...
# FEATURE DATA TYPES
# ...
# [dtype('int64')]

# %%
print("Dataset Shape:", df.shape)

print("\nDisease Counts:")
print(df["Disease"].value_counts())

print("\nFirst Five Rows:")
display(df.head())
# Out:
# Dataset Shape: (146, 18)
#
# Disease Counts:
# Disease
# Migraine                        10
# Chicken pox                     10
# Diabetes                         9
# Jaundice                         9
# Typhoid                          9
# Tuberculosis                     9
# Common Cold                      9
# Pneumonia                        9
# Hypoglycemia                     9
# Malaria                          8
# Bronchial Asthma                 7
# Drug Reaction                    6
# Hypertension                     6
# Arthritis                        6
# Allergy                          5
# AIDS                             5
# Gastroenteritis                  5
# Paralysis (brain hemorrhage)     5
# Heart attack                     5
# Urinary tract infection          5
# Name: count, dtype: int64
#
# First Five Rows:
#    Disease            Symptom_1  Symptom_2           Symptom_3  \
# 0  Allergy  continuous_sneezing  shivering              chills
# ...

# %%
#Just verify that the feature names are correct
print(X_encoded.shape)
print(X_encoded.columns[:20])
# Out:
# (146, 217)
# Index(['Symptom_1_acidity', 'Symptom_1_bladder_discomfort',
#        'Symptom_1_breathlessness', 'Symptom_1_burning_micturition',
#        'Symptom_1_chest_pain', 'Symptom_1_chills',
#        'Symptom_1_continuous_sneezing', 'Symptom_1_cough', 'Symptom_1_fatigue',
#        'Symptom_1_headache', 'Symptom_1_indigestion', 'Symptom_1_itching',
#        'Symptom_1_muscle_wasting', 'Symptom_1_muscle_weakness',
#        'Symptom_1_patches_in_throat', 'Symptom_1_shivering',
#        'Symptom_1_skin_rash', 'Symptom_1_stiff_neck', 'Symptom_1_sunken_eyes',
#        'Symptom_1_vomiting'],
#       dtype='str')
